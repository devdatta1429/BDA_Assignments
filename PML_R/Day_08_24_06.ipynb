# %% [markdown]
# <a href="https://colab.research.google.com/github/devdatta1429/BDA_Assignments/blob/main/PML_R/Day_08_24_06.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 🔰Encoder and decoder🔰

# %% [markdown]
# context vector\
# machine translation
#
#
#
# H0--> i love cats -----> context vector\
# context vector---->
#
#
#
# autoregressive\
# in the decoder architeture each of the step is auto regressive\
#
# input:
# i love llamms
#
# for gernerating the next word , first the all previously generated words are consumed.\
# i love llamms --> ik
# i love llamms | ik--> hou
# and the model generates the first token

# %% [markdown]
# transformer encode decoder\
# input sentence :
#
#
#
# [https://poloclub.github.io/transformer-explainer/](https://poloclub.github.io/transformer-explainer/)

# %% [markdown]
# thinking machines
