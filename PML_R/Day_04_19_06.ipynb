# %% [markdown]
# <a href="https://colab.research.google.com/github/devdatta1429/BDA_Assignments/blob/main/PML_R/Day_04_19_06.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import nltk

import matplotlib.pyplot as plt
from nltk.tokenize import word_tokenize
from nltk.stem import PorterStemmer
from nltk.stem import WordNetLemmatizer
from nltk import pos_tag

from nltk.corpus import stopwords
import re
from collections import Counter


nltk.download('punkt_tab')
nltk.download('averaged_perceptron_tagger')
nltk.download('wordnet')
nltk.download('stopwords')

from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics import accuracy_score, classification_report
# Out:
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger.zip.
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.

# %%
from sklearn.feature_extraction.text import CountVectorizer
# Sample documents
documents = [
    "I love NLP",
    "NLP is interesting",
    "I love machine learning"
]

# Create BoW model
vectorizer = CountVectorizer() #creates vocabulary


# Convert text into BoW matrix
X = vectorizer.fit_transform(documents)#counts occurances based on vocabulary

# Display as table
df = pd.DataFrame(
    X.toarray(),#sparse matrix to normal
    columns=vectorizer.get_feature_names_out()
)

print(df)
# Out:
#    interesting  is  learning  love  machine  nlp
# 0            0   0         0     1        0    1
# 1            1   1         0     0        0    1
# 2            0   0         1     1        1    0

# %% [markdown]
# TF:How often a word appears in a document
# IDF:Gives less importance to words appearing in many documents.

# %%
from sklearn.feature_extraction.text import TfidfVectorizer


# Sample documents
documents = [
    "I love NLP",
    "NLP is interesting",
    "I love machine learning"
]

# Create TF-IDF model
vectorizer = TfidfVectorizer()

# Convert text into TF-IDF matrix
X = vectorizer.fit_transform(documents)

# Display as table
df = pd.DataFrame(
    X.toarray(),
    columns=vectorizer.get_feature_names_out()
)

print(df.round(2))
# Out:
#    interesting    is  learning  love  machine   nlp
# 0         0.00  0.00      0.00  0.71     0.00  0.71
# 1         0.62  0.62      0.00  0.00     0.00  0.47
# 2         0.00  0.00      0.62  0.47     0.62  0.00

# %% [markdown]
# For Document 0, the most important terms are "love" and "nlp" (TF-IDF = 0.71).
#
# For Document 1, the most important terms are "interesting" and "is" (TF-IDF = 0.62).
#
# For Document 2, the most important terms are "machine" and "learning" (TF-IDF = 0.62).
#
# Words with higher TF-IDF values contribute more to distinguishing one document from the others.
#
# So TF-IDF is often preferred over Bag of Words for text classification and information retrieval.

# %%
query = ["machine learning"]

# %%
query_vector = vectorizer.transform(query)
print(query_vector.toarray())
# Out:
# [[0.         0.         0.70710678 0.         0.70710678 0.        ]]

# %%
from sklearn.metrics.pairwise import cosine_similarity

scores = cosine_similarity(query_vector, X)

print(scores)
# Out:
# [[0.         0.         0.88072413]]

# %%
import pandas as pd
import nltk

import matplotlib.pyplot as plt
from nltk.tokenize import word_tokenize
from nltk.stem import PorterStemmer
from nltk.stem import WordNetLemmatizer
from nltk import pos_tag

from nltk.corpus import stopwords
import re
from collections import Counter

import os
os.chdir('/content/drive/MyDrive/CDAC/')


nltk.download('punkt_tab')
nltk.download('averaged_perceptron_tagger')
nltk.download('wordnet')
nltk.download('stopwords')

from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics import accuracy_score, classification_report
# Out:
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
df=pd.read_csv("spam.csv",encoding="latin1")
df.head()
# Out:
#   label                                            message Unnamed: 2  \
# 0   ham  Go until jurong point, crazy.. Available only ...        NaN
# 1   ham                      Ok lar... Joking wif u oni...        NaN
# 2  spam  Free entry in 2 a wkly comp to win FA Cup fina...        NaN
# 3   ham  U dun say so early hor... U c already then say...        NaN
# 4   ham  Nah I don't think he goes to usf, he lives aro...        NaN
#
#   Unnamed: 3 Unnamed: 4
# 0        NaN        NaN
# 1        NaN        NaN
# 2        NaN        NaN
# 3        NaN        NaN
# 4        NaN        NaN

# %%
df=df.drop(["Unnamed: 2","Unnamed: 3","Unnamed: 4"],axis=1)
df.head()
# Out:
#   label                                            message
# 0   ham  Go until jurong point, crazy.. Available only ...
# 1   ham                      Ok lar... Joking wif u oni...
# 2  spam  Free entry in 2 a wkly comp to win FA Cup fina...
# 3   ham  U dun say so early hor... U c already then say...
# 4   ham  Nah I don't think he goes to usf, he lives aro...

# %%
lemmatizer = WordNetLemmatizer()
stop_words = set(stopwords.words('english'))

def preprocess(text):

    # lowercase
    text = text.lower()

    # remove special characters except englih characters
    text = re.sub(r'[^a-zA-Z]', ' ', text)

    # tokenize
    words = nltk.word_tokenize(text)

    # remove stopwords and lemmatize
    words = [
        lemmatizer.lemmatize(word)
        for word in words
        if word not in stop_words
    ]

    return " ".join(words)

# %%
df.iloc[4]
# Out:
# label                                                    ham
# message    Nah I don't think he goes to usf, he lives aro...
# Name: 4, dtype: object

# %%
df['clean']=df['message'].apply(preprocess)

# %%
df[25:50]
# Out:
#    label                                            message  \
# 25   ham  Just forced myself to eat a slice. I'm really ...
# 26   ham                     Lol your always so convincing.
# 27   ham  Did you catch the bus ? Are you frying an egg ...
# 28   ham  I'm back &amp; we're packing the car now, I'll...
# 29   ham  Ahhh. Work. I vaguely remember that! What does...
# 30   ham  Wait that's still not all that clear, were you...
# 31   ham  Yeah he got in at 2 and was v apologetic. n ha...
# 32   ham                      K tell me anything about you.
# 33   ham  For fear of fainting with the of all that hous...
# 34  spam  Thanks for your subscription to Ringtone UK yo...
# 35   ham  Yup... Ok i go home look at the timings then i...
# 36   ham    Oops, I'll let you know when my roommate's done
# 37   ham                       I see the letter B on my car
# 38   ham                        Anything lor... U decide...
# 39   ham  Hello! How's you and how did saturday go? I wa...
# ...

# %%
df['label'] = df['label'].map({
    'ham': 0,
    'spam': 1
})

# %%
df['label'].value_counts()
# Out:
# label
# 0    4825
# 1     747
# Name: count, dtype: int64

# %%
X = df['message']
y = df['label']

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

tfidf = TfidfVectorizer()
X_tfidf = tfidf.fit_transform(X)

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(
    X_tfidf, y,
    test_size=0.2,
    random_state=42,
    stratify=y
)

# %%
X_train.shape, X_test.shape
# Out:
# ((4457, 8672), (1115, 8672))

# %%
y_train.value_counts()
# Out:
# label
# 0    3859
# 1     598
# Name: count, dtype: int64

# %%
from sklearn.linear_model import LogisticRegression

model = LogisticRegression(class_weight='balanced',max_iter=1000)
model.fit(X_train, y_train)
# Out:
# LogisticRegression(class_weight='balanced', max_iter=1000)

# %%
predictions = model.predict(X_test)

# %%
predictions
# Out:
# array([0, 0, 0, ..., 0, 0, 0])

# %%
print("Accuracy:", accuracy_score(y_test, predictions))

print(classification_report(y_test, predictions))
# Out:
# Accuracy: 0.9802690582959641
#               precision    recall  f1-score   support
#
#            0       0.98      0.99      0.99       966
#            1       0.96      0.89      0.92       149
#
#     accuracy                           0.98      1115
#    macro avg       0.97      0.94      0.96      1115
# weighted avg       0.98      0.98      0.98      1115

# %%
new_emails = [

     "Hi Chetan, the meeting is scheduled at 10 AM tomorrow.",

    "Claim your prize money immediately."
]

# %%
clean_emails = []

for email in new_emails:
    clean_emails.append(preprocess(email))

# %%
email_vectors = tfidf.transform(clean_emails)

# %%
predictions = model.predict(email_vectors)

# %%
predictions
# Out:
# array([0, 1])

# %%
for email, pred in zip(new_emails, predictions):

    if pred == 1:
        result = "Spam"
    else:
        result = "Ham"

    print("\nEmail:", email)
    print("Prediction:", result)
# Out:
# Email: Hi Chetan, the meeting is scheduled at 10 AM tomorrow.
# Prediction: Ham
#
# Email: Claim your prize money immediately.
# Prediction: Spam
