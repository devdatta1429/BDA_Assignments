# %% [markdown]
# ### Data Reading

# %%
dbutils.fs.ls("/Volumes/workspace/default/my_unity_catlog/")

# %%
df = spark.read.format('csv').option('inferSchema',True).option('header',True).load('/Volumes/workspace/default/my_unity_catlog/BigMart Sales.csv')

# %%
df.show(5)

# %%
df1 = spark.read.table("workspace.default.big_mart_sales")

df1.show(5)

# %%
# %sql
select * from big_mart_sales limit 5;

# %%
# %sql
select * from big_mart_sales;
