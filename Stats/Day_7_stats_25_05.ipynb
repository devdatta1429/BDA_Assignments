# %% [markdown]
# <a href="https://colab.research.google.com/github/devdatta1429/BDA_Assignments/blob/main/Stats/Day_7_stats_25_05.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %%
import scipy
from scipy import stats
from scipy.stats import binom, poisson , norm , t

# %%
binom.pmf(50, 80, 0.5)
# Out:
# np.float64(0.007338260454779909)

# %%
1 - binom.cdf(49, 80 , 0.7)
# Out:
# np.float64(0.9412518864088271)

# %%
# exactly upto 5 days
poisson.pmf(5,7)
# Out:
# np.float64(0.1277166682922895)
