# %% [markdown]
# <a href="https://colab.research.google.com/github/devdatta1429/BDA_Assignments/blob/main/Stats/Day_8_stats_26_05.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %%
import seaborn as sns
import matplotlib
import matplotlib.pyplot as plt
import pylab
from pylab import legend
from pylab import plot, show, title, xlabel ,ylabel

# %%
df = pd.read_excel('/content/drive/MyDrive/CDAC_DataBook.xlsx' , sheet_name ='ERPData')

# %%
grp1 = df.groupby('MaterialID')
df1 = grp1.Quantity.agg('sum')
df1.plot(kind='bar')
# Out:
# <Axes: xlabel='MaterialID'>

# %%
grp1 = df.groupby(df.MaterialID)
df1 = grp1.size()
df1.plot(kind ='bar')
# Out:
# <Axes: xlabel='MaterialID'>

# %%
df2 = pd.crosstab(df.MaterialID, df.Location)
print(df2)


df2.plot(kind='bar')
# Out:
# Location    MWH-1  MWH-2  MWH-3  MWH-4  MWH-5
# MaterialID
# AXCP-78         5      1      1      1      3
# DDBN-89         3      1      1      2      1
# GCVB-79         0      4      0      0      1
# LXCV-21         0      1      1      0      3
# SDRT-67         2      1      0      1      2
# TMI-43T         1      1      1     11      1
# <Axes: xlabel='MaterialID'>

# %%
df3 = pd.crosstab(df.MaterialID, df.Location , values=df.Quantity , aggfunc='sum')
print(df3          ,end='\n\n')


df3.plot(kind='bar')
# Out:
# Location    MWH-1  MWH-2  MWH-3  MWH-4  MWH-5
# MaterialID
# AXCP-78     548.0   85.0   29.0   36.0  200.0
# DDBN-89     130.0   69.0   38.0   75.0   71.0
# GCVB-79       NaN  156.0    NaN    NaN   26.0
# LXCV-21       NaN   27.0   42.0    NaN  174.0
# SDRT-67      91.0   31.0    NaN   58.0  114.0
# TMI-43T     120.0   29.0   65.0  559.0  112.0
# <Axes: xlabel='MaterialID'>

# %%
df4 = df.pivot_table(values='Quantity' , index = 'MaterialID' , columns ='Location' , aggfunc='sum')
df4.plot(kind = 'bar')
# Out:
# <Axes: xlabel='MaterialID'>

# %%
df = pd.read_excel('/content/drive/MyDrive/CDAC_DataBook.xlsx', sheet_name='ERPData')
grp1 = df.groupby('MaterialID')
df1 = grp1.Quantity.agg('sum')
df1.plot(kind='bar')

df2 = pd.crosstab(df.MaterialID, df.Location)
df2.plot(kind='bar')

df3 = pd.crosstab(df.MaterialID, df.Location, values=df.Quantity, aggfunc='sum')
df3.plot(kind='bar')

df4 =df.pivot_table(values='Quantity',index='MaterialID',columns='Location',aggfunc='sum')
df4.plot(kind='bar')

x1= [5,6,4,3,5,6,7,8,9,6,6,3,6]
x2 = [3,5,4,5,6,7,6,5,4,5,6,7,8,2,3,5]
x3 = [4,5,3,4,5,7,8,9,4,3,6,8]

plt.boxplot([x1,x2,x3])

df = pd.read_excel('/content/drive/MyDrive/CDAC_DataBook.xlsx', sheet_name='faithful')
plt.scatter(df.eruptions, df.waiting)

# %%
x1= [5,6,4,3,5,6,7,8,9,6,6,3,6]
x2 = [3,5,4,5,6,7,6,5,4,5,6,7,8,2,3,5]
x3 = [4,5,3,4,5,7,8,9,4,3,6,8]

plt.boxplot([x1,x2,x3])
sns.boxplot([x1,x2,x3])
# Out:
# <Axes: >

# %%
df = pd.read_excel('/content/drive/MyDrive/CDAC_DataBook.xlsx' , sheet_name ='faithful')

# %%
plt.scatter(df.eruptions, df.waiting)

# %%
sns.scatterplot(x = df.waiting , y = df.eruptions)
# Out:
# <Axes: xlabel='waiting', ylabel='eruptions'>

# %%
cats = [1,2,3,4,5]
# plt.hist(df.eruptions,cats)
plt.hist(df.eruptions)
# Out:
# (array([45., 36., 13.,  3.,  4., 12., 29., 52., 54., 24.]),
#  array([1.6 , 1.95, 2.3 , 2.65, 3.  , 3.35, 3.7 , 4.05, 4.4 , 4.75, 5.1 ]),
#  <BarContainer object of 10 artists>)

# %%
sns.histplot(df.eruptions)
# Out:
# <Axes: xlabel='eruptions', ylabel='Count'>

# %%
df1 = df.iloc[np.where(df.eruptions <= 3.6)]
df2 = df.iloc[np.where(df.eruptions > 3.6)]

plt.figure(figsize=(6,4))

plt.scatter(df1.eruptions , df1.waiting , c='red')
plt.scatter(df2.eruptions , df2.waiting , c='blue')
plt.show()

# %%
group1 = np.random.normal(loc=10, scale=2, size=100)  # Volcano A mean is 10 and std dev=2
group2 = np.random.normal(loc=12, scale=2.5, size=100)  # e.g., Volcano B

bins = np.linspace(5, 20, 15)  # common bin edges for both groups

plt.hist(group1, bins=bins, alpha=0.6, label='Volcano A', color='blue', edgecolor='black')
plt.hist(group2, bins=bins, alpha=0.6, label='Volcano B', color='yellow', edgecolor='black')
plt.show()

# %% [markdown]
# #

# %%
df = sns.load_dataset('titanic')
class_counts = df['class'].value_counts()
# matplot lib
plt.bar(class_counts.index , class_counts.values)
# Out:
# <BarContainer object of 3 artists>

# %%
#seaborn
df['class'].value_counts()

sns.barplot(x ='class' , y='fare' ,data=df , ci =None)
# Out:
# /tmp/ipykernel_796/1879406610.py:4: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(x ='class' , y='fare' ,data=df , ci =None)
# <Axes: xlabel='class', ylabel='fare'>

# %%
sns.barplot( x = 'MaterialID' , y = 'Quantity' , hue = 'Location' ,data = df, ci=None ,estimator=np.sum)
# Out:
# /tmp/ipykernel_796/1832681135.py:1: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot( x = 'MaterialID' , y = 'Quantity' , hue = 'Location' ,data = df, ci=None ,estimator=np.sum)
# <Axes: xlabel='MaterialID', ylabel='Quantity'>

# %% [markdown]
# #
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# #

# %%
df = pd.read_excel('/content/drive/MyDrive/ManHours.xlsx')
df.head()
# Out:
#   Name Client  Hours Grade  Team
# 0    A   CDAC      3     A     2
# 1    B   CDAC      4     A     2
# 2    A   Infy      2     B     1
# 3    C   Infy      4     C     3
# 4    A   CDAC      3     A     2

# %%
len(df.value_counts())
# Out:
# 15

# %%
360*0.12 + 360*0.38 + 360*0.5
# Out:
# 360.0

# %%
df = pd.read_csv('/content/drive/MyDrive/6-Churn_ModellingDataSet.csv')
df.head()
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0          1    15634602  Hargrave          619    France  Female   42
# 1          2    15647311      Hill          608     Spain  Female   41
# 2          3    15619304      Onio          502    France  Female   42
# 3          4    15701354      Boni          699    France  Female   39
# 4          5    15737888  Mitchell          850     Spain  Female   43
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2       0.00              1          1               1
# 1       1   83807.86              1          0               1
# 2       8  159660.80              3          1               0
# 3       1       0.00              2          0               0
# 4       2  125510.82              1          1               1
#
#    EstimatedSalary  Exited
# 0        101348.88       1
# 1        112542.58       0
# 2        113931.57       1
# 3         93826.63       0
# 4         79084.10       0

# %%
df = df.drop(['RowNumber' , 'CustomerId' , 'Surname'] , axis= 1)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   CreditScore      10000 non-null  int64
#  1   Geography        10000 non-null  object
#  2   Gender           10000 non-null  object
#  3   Age              10000 non-null  int64
#  4   Tenure           10000 non-null  int64
#  5   Balance          10000 non-null  float64
#  6   NumOfProducts    10000 non-null  int64
#  7   HasCrCard        10000 non-null  int64
#  8   IsActiveMember   10000 non-null  int64
#  9   EstimatedSalary  10000 non-null  float64
#  10  Exited           10000 non-null  int64
# dtypes: float64(2), int64(7), object(2)
# memory usage: 859.5+ KB

# %% [markdown]
# Non-null all give 10000 means there is no null values.

# %%
plt.boxplot(df.Balance)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7b9fc56c8da0>,
#   <matplotlib.lines.Line2D at 0x7b9fc62a3200>],
#  'caps': [<matplotlib.lines.Line2D at 0x7b9fc5895550>,
#   <matplotlib.lines.Line2D at 0x7b9fc65f27e0>],
#  'boxes': [<matplotlib.lines.Line2D at 0x7b9fc55c4ef0>],
#  'medians': [<matplotlib.lines.Line2D at 0x7b9fc5616720>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7b9fc56a1400>],
#  'means': []}

# %%
plt.boxplot(df.Age)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7b9fc567a9f0>,
#   <matplotlib.lines.Line2D at 0x7b9fc567a1e0>],
#  'caps': [<matplotlib.lines.Line2D at 0x7b9fc5703680>,
#   <matplotlib.lines.Line2D at 0x7b9fc5702090>],
#  'boxes': [<matplotlib.lines.Line2D at 0x7b9fc5769370>],
#  'medians': [<matplotlib.lines.Line2D at 0x7b9fc5701a90>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7b9fc5895b20>],
#  'means': []}

# %%
len(np.where(df.Exited == 1)[0])

df.Exited.value_counts()

grp1 = df.groupby("Exited")
grp1['Exited'].agg['sum']

# %%
df1 = df.Exited.value_counts()
df1

df1 = pd.DataFrame(df1)
df1

df1['prop'] = df1['count'] / df1['count'].sum()
print(df1)
# Out:
#         count    prop
# Exited
# 0        7963  0.7963
# 1        2037  0.2037

# %%
df0 = df.iloc[np.where(df.Exited == 0)]
df1 = df.iloc[np.where(df.Exited == 1)]

plt.boxplot([df0.EstimatedSalary , df1.EstimatedSalary])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7b9fc53bb050>,
#   <matplotlib.lines.Line2D at 0x7b9fc53bb380>,
#   <matplotlib.lines.Line2D at 0x7b9fc567a540>,
#   <matplotlib.lines.Line2D at 0x7b9fc5437140>],
#  'caps': [<matplotlib.lines.Line2D at 0x7b9fc53bb6b0>,
#   <matplotlib.lines.Line2D at 0x7b9fc53bb980>,
#   <matplotlib.lines.Line2D at 0x7b9fc5434a40>,
#   <matplotlib.lines.Line2D at 0x7b9fc5435ee0>],
#  'boxes': [<matplotlib.lines.Line2D at 0x7b9fc53badb0>,
#   <matplotlib.lines.Line2D at 0x7b9fc5425280>],
#  'medians': [<matplotlib.lines.Line2D at 0x7b9fc533d8e0>,
#   <matplotlib.lines.Line2D at 0x7b9fc53b9e20>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7b9fc53e3b60>,
#   <matplotlib.lines.Line2D at 0x7b9fc53bbc80>],
#  'means': []}

# %%
plt.boxplot([df0.Age , df1.Age])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7b9fc52389e0>,
#   <matplotlib.lines.Line2D at 0x7b9fc5238ce0>,
#   <matplotlib.lines.Line2D at 0x7b9fc5239ca0>,
#   <matplotlib.lines.Line2D at 0x7b9fc5239f40>],
#  'caps': [<matplotlib.lines.Line2D at 0x7b9fc5238f80>,
#   <matplotlib.lines.Line2D at 0x7b9fc5239250>,
#   <matplotlib.lines.Line2D at 0x7b9fc523a210>,
#   <matplotlib.lines.Line2D at 0x7b9fc523a540>],
#  'boxes': [<matplotlib.lines.Line2D at 0x7b9fc5238740>,
#   <matplotlib.lines.Line2D at 0x7b9fc52399d0>],
#  'medians': [<matplotlib.lines.Line2D at 0x7b9fc52394f0>,
#   <matplotlib.lines.Line2D at 0x7b9fc523a840>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7b9fc5239760>,
#   <matplotlib.lines.Line2D at 0x7b9fc523ab10>],
#  'means': []}

# %%
plt.boxplot([df0.CreditScore , df1.CreditScore])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7b9fc529a480>,
#   <matplotlib.lines.Line2D at 0x7b9fc529a7b0>,
#   <matplotlib.lines.Line2D at 0x7b9fc5c2f7a0>,
#   <matplotlib.lines.Line2D at 0x7b9fc533ef30>],
#  'caps': [<matplotlib.lines.Line2D at 0x7b9fc529aa80>,
#   <matplotlib.lines.Line2D at 0x7b9fc529ad50>,
#   <matplotlib.lines.Line2D at 0x7b9fc533f470>,
#   <matplotlib.lines.Line2D at 0x7b9fc51f22d0>],
#  'boxes': [<matplotlib.lines.Line2D at 0x7b9fc529a1e0>,
#   <matplotlib.lines.Line2D at 0x7b9fc529b5c0>],
#  'medians': [<matplotlib.lines.Line2D at 0x7b9fc529b050>,
#   <matplotlib.lines.Line2D at 0x7b9fc51f2db0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7b9fc529b320>,
#   <matplotlib.lines.Line2D at 0x7b9fc52c5910>],
#  'means': []}

# %%
df400 = df.iloc[np.where(df.CreditScore <= 400)]
# print(df400)
exit400 = df400.Exited.value_counts()
exit400
# Out:
# Exited
# 1    19
# Name: count, dtype: int64

# %%
df500 = df.iloc[np.where(df.CreditScore <= 500)]
# print(df400)
exit500 = df500.Exited.value_counts()
exit500
# Out:
# Exited
# 0    491
# 1    152
# Name: count, dtype: int64

# %%
(152/(152+491))*100
# Out:
# 23.63919129082426

# %%
dfcross = pd.crosstab(df.Geography , df.Exited)
print(dfcross)
print()

dfcross1 = pd.DataFrame(dfcross)

dfcross1['prop_all'] = dfcross1[1] / (dfcross1[1]+dfcross1[0])
dfcross1['comapre_non-exit'] = dfcross1[1] / dfcross1[0]
print(dfcross1)
print()

dfcross.plot(kind = 'bar')
# Out:
# Exited        0    1
# Geography
# France     4204  810
# Germany    1695  814
# Spain      2064  413
#
# Exited        0    1  prop_all  comapre_non-exit
# Geography
# France     4204  810  0.161548          0.192674
# Germany    1695  814  0.324432          0.480236
# Spain      2064  413  0.166734          0.200097
# <Axes: xlabel='Geography'>

# %%
cc = pd.crosstab(df.HasCrCard , df.Exited)

cc['prop_all'] = cc[1] / (cc[1]+cc[0])
print(cc)
print()

cc.plot(kind= 'bar')
# Out:
# Exited        0     1  prop_all
# HasCrCard
# 0          2332   613  0.208149
# 1          5631  1424  0.201843
# <Axes: xlabel='HasCrCard'>

# %%
1139  /(1139 +  898)

(df.Gender == 'Female').sum()
# Out:
# np.int64(4543)

# %%
gender = pd.crosstab(df.Gender , df.Exited)

gender['prop_all'] = gender[1] / (gender[1] + gender[0])
print(gender)
print()

gender.plot(kind= 'bar')
# Out:
# Exited     0     1  prop_all
# Gender
# Female  3404  1139  0.250715
# Male    4559   898  0.164559
# <Axes: xlabel='Gender'>

# %%
pt = pd.crosstab( df.Geography, df.Gender , df.Exited , aggfunc='sum')
print(pt)
print()

pt['prop'] = pt['Female'] / (pt['Female']+ pt['Male'])
print(pt)
print()

pt.plot(kind = 'bar')
# Out:
# Gender     Female  Male
# Geography
# France        460   350
# Germany       448   366
# Spain         231   182
#
# Gender     Female  Male      prop
# Geography
# France        460   350  0.567901
# Germany       448   366  0.550369
# Spain         231   182  0.559322
# <Axes: xlabel='Geography'>

# %%
tb1 = pd.crosstab(df.IsActiveMember , df.Exited)
tb1.plot.bar()

tb1['Prop'] = tb1[1] /(tb1[0] + tb1[1])
tb1
# Out:
# Exited             0     1      Prop
# IsActiveMember
# 0               3547  1302  0.268509
# 1               4416   735  0.142691
