# %% [markdown]
# <a href="https://colab.research.google.com/github/devdatta1429/BDA_Assignments/blob/main/Stats/Day_3_Pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ## data cleaning
# missing values\
# duplicates values\
# data validation

# %%
df = pd.read_excel('/content/drive/MyDrive/CDAC_DataBook.xlsx' ,sheet_name='ERPData')
df.head(5)
# Out:
#   MaterialID Location  Quantity
# 0    TMI-43T    MWH-4        34
# 1    AXCP-78    MWH-1        67
# 2    LXCV-21    MWH-2        27
# 3    AXCP-78    MWH-5        65
# 4    AXCP-78    MWH-4        36

# %%
df.tail(3)
# Out:
#    MaterialID Location  Quantity
# 47    AXCP-78    MWH-3        29
# 48    AXCP-78    MWH-1        75
# 49    DDBN-89    MWH-1        39

# %%
df.shape #Giving dimensions(rows X columns) of the table
# Out:
# (50, 3)

# %% [markdown]
# #

# %%
np.unique(df['MaterialID'])
# Out:
# array(['AXCP-78', 'DDBN-89', 'GCVB-79', 'LXCV-21', 'SDRT-67', 'TMI-43T'],
#       dtype=object)

# %%
np.unique(df.MaterialID) # df['MaterialID'] this will use for if there is space between name
# Out:
# array(['AXCP-78', 'DDBN-89', 'GCVB-79', 'LXCV-21', 'SDRT-67', 'TMI-43T'],
#       dtype=object)

# %%
np.unique(df['MaterialID']).reshape(-1,1)
# Out:
# array([['AXCP-78'],
#        ['DDBN-89'],
#        ['GCVB-79'],
#        ['LXCV-21'],
#        ['SDRT-67'],
#        ['TMI-43T']], dtype=object)

# %%
print(np.unique(df['MaterialID']).reshape(-1,1))
# Out:
# [['AXCP-78']
#  ['DDBN-89']
#  ['GCVB-79']
#  ['LXCV-21']
#  ['SDRT-67']
#  ['TMI-43T']]

# %%
len(np.unique(df.MaterialID))
# Out:
# 6

# %%
print(np.unique(df.Location))
len(np.unique(df.Location))
# Out:
# ['MWH-1' 'MWH-2' 'MWH-3' 'MWH-4' 'MWH-5']
# 5

# %%
len(np.unique(df.Quantity))
# Out:
# 35

# %%
df.iloc[[2,3,4]]
# Out:
#   MaterialID Location  Quantity
# 2    LXCV-21    MWH-2        27
# 3    AXCP-78    MWH-5        65
# 4    AXCP-78    MWH-4        36

# %%
df.columns.values
# Out:
# array(['MaterialID', 'Location', 'Quantity'], dtype=object)

# %%
df['MaterialID'].head()
# Out:
# 0    TMI-43T
# 1    AXCP-78
# 2    LXCV-21
# 3    AXCP-78
# 4    AXCP-78
# Name: MaterialID, dtype: object

# %%
df.columns.values[0] = 'MaterialID'
df.head()
# Out:
#   MaterialID Location  Quantity
# 0    TMI-43T    MWH-4        34
# 1    AXCP-78    MWH-1        67
# 2    LXCV-21    MWH-2        27
# 3    AXCP-78    MWH-5        65
# 4    AXCP-78    MWH-4        36

# %%
ind = np.where(df.Quantity >= 70)
df1 = df.iloc[ind]
print(df1,          end='\n\n')
df1.reset_index(drop=True)
# Out:
#    MaterialID Location  Quantity
# 5     TMI-43T    MWH-4        78
# 9     TMI-43T    MWH-1       120
# 12    TMI-43T    MWH-4        76
# 15    GCVB-79    MWH-2        87
# 17    SDRT-67    MWH-5       102
# 21    TMI-43T    MWH-4        75
# 23    DDBN-89    MWH-5        71
# 24    AXCP-78    MWH-1       152
# 25    AXCP-78    MWH-1       109
# 27    LXCV-21    MWH-5        83
# 33    TMI-43T    MWH-5       112
# 38    AXCP-78    MWH-5        70
# 39    AXCP-78    MWH-1       145
# 46    AXCP-78    MWH-2        85
# 48    AXCP-78    MWH-1        75
#    MaterialID Location  Quantity
# 0     TMI-43T    MWH-4        78
# 1     TMI-43T    MWH-1       120
# 2     TMI-43T    MWH-4        76
# 3     GCVB-79    MWH-2        87
# 4     SDRT-67    MWH-5       102
# 5     TMI-43T    MWH-4        75
# 6     DDBN-89    MWH-5        71
# 7     AXCP-78    MWH-1       152
# 8     AXCP-78    MWH-1       109
# 9     LXCV-21    MWH-5        83
# 10    TMI-43T    MWH-5       112
# ...

# %%
ind
# Out:
# (array([ 5,  9, 12, 15, 17, 21, 23, 24, 25, 27, 33, 38, 39, 46, 48]),)

# %%
len(ind[0])
# Out:
# 15

# %%
(df.Quantity >= 70).sum()
# Out:
# np.int64(15)

# %% [markdown]
# ##
# #
# #
# #
# #
# #

# %%
ind = np.where((df1.Quantity > 70) & (df1.Location == 'MWH-1'))

print(ind            ,end='\n\n')

print(df1.iloc[ind]                     ,end='\n\n')

fd = df1.iloc[ind]
er = fd.reset_index(drop=True)
print(er                      ,end='\n\n')

len(ind[0])
# Out:
# (array([ 3, 12, 13, 21, 25]),)
#
#    MaterialID Location  Quantity Grade
# 3     TMI-43T    MWH-1       120     C
# 12    AXCP-78    MWH-1       152     C
# 13    AXCP-78    MWH-1       109     C
# 21    AXCP-78    MWH-1       145     C
# 25    AXCP-78    MWH-1        75     B
#
#   MaterialID Location  Quantity Grade
# 0    TMI-43T    MWH-1       120     C
# 1    AXCP-78    MWH-1       152     C
# 2    AXCP-78    MWH-1       109     C
# 3    AXCP-78    MWH-1       145     C
# 4    AXCP-78    MWH-1        75     B
# 5

# %%
ind = np.where((df.Quantity >=70) | (df.Location == 'MWH-1'))

print(ind                     ,end='\n\n')

df.iloc[ind]
# Out:
# (array([ 1,  5,  9, 10, 12, 15, 17, 21, 23, 24, 25, 26, 27, 33, 38, 39, 40,
#        41, 46, 48, 49]),)
#    MaterialID Location  Quantity
# 1     AXCP-78    MWH-1        67
# 5     TMI-43T    MWH-4        78
# 9     TMI-43T    MWH-1       120
# 10    SDRT-67    MWH-1        34
# 12    TMI-43T    MWH-4        76
# 15    GCVB-79    MWH-2        87
# 17    SDRT-67    MWH-5       102
# 21    TMI-43T    MWH-4        75
# 23    DDBN-89    MWH-5        71
# 24    AXCP-78    MWH-1       152
# 25    AXCP-78    MWH-1       109
# 26    DDBN-89    MWH-1        57
# 27    LXCV-21    MWH-5        83
# 33    TMI-43T    MWH-5       112
# 38    AXCP-78    MWH-5        70
# 39    AXCP-78    MWH-1       145
# 40    DDBN-89    MWH-1        34
# 41    SDRT-67    MWH-1        57
# 46    AXCP-78    MWH-2        85
# 48    AXCP-78    MWH-1        75
# 49    DDBN-89    MWH-1        39

# %%
ind = np.where(df.Location == 'MWH-2')

print(ind                     ,end='\n\n')

print(df.iloc[ind]                      ,end='\n\n')

df.iloc[ind]['Quantity'].sum()
# Out:
# (array([ 2,  7,  8, 15, 35, 36, 42, 45, 46]),)
#
#    MaterialID Location  Quantity
# 2     LXCV-21    MWH-2        27
# 7     TMI-43T    MWH-2        29
# 8     GCVB-79    MWH-2        10
# 15    GCVB-79    MWH-2        87
# 35    GCVB-79    MWH-2        31
# 36    GCVB-79    MWH-2        28
# 42    SDRT-67    MWH-2        31
# 45    DDBN-89    MWH-2        69
# 46    AXCP-78    MWH-2        85
# np.int64(397)

# %%
ind = np.where(df.Quantity < 50 )
print(ind                      ,end='\n\n')
df1 = df.drop(ind[0]).reset_index(drop = True)
df1.head()
# Out:
# (array([ 0,  2,  4,  6,  7,  8, 10, 13, 16, 18, 20, 22, 28, 30, 32, 34, 35,
#        36, 40, 42, 43, 44, 47, 49]),)
#   MaterialID Location  Quantity
# 0    AXCP-78    MWH-1        67
# 1    AXCP-78    MWH-5        65
# 2    TMI-43T    MWH-4        78
# 3    TMI-43T    MWH-1       120
# 4    SDRT-67    MWH-4        58

# %%
min(df.Quantity)
# Out:
# 10

# %%
max(df.Quantity)
# Out:
# 152

# %%
len(df1)
# Out:
# 26

# %%
new_df = np.empty((len(df1),1))
new_df

df2 = np.hstack((df1,new_df))
df2
# Out:
# array([['AXCP-78', 'MWH-1', 67, 3.3e-322],
#        ['AXCP-78', 'MWH-5', 65, 3.2e-322],
#        ['TMI-43T', 'MWH-4', 78, 3.85e-322],
#        ['TMI-43T', 'MWH-1', 120, 5.93e-322],
#        ['SDRT-67', 'MWH-4', 58, 2.87e-322],
#        ['TMI-43T', 'MWH-4', 76, 3.75e-322],
#        ['TMI-43T', 'MWH-3', 65, 3.2e-322],
#        ['GCVB-79', 'MWH-2', 87, 4.3e-322],
#        ['SDRT-67', 'MWH-5', 102, 5.04e-322],
#        ['TMI-43T', 'MWH-4', 52, 2.57e-322],
#        ['TMI-43T', 'MWH-4', 75, 3.7e-322],
#        ['DDBN-89', 'MWH-5', 71, 3.5e-322],
#        ['AXCP-78', 'MWH-1', 152, 7.5e-322],
#        ['AXCP-78', 'MWH-1', 109, 5.4e-322],
#        ['DDBN-89', 'MWH-1', 57, 2.8e-322],
#        ['LXCV-21', 'MWH-5', 83, 4.1e-322],
#        ['LXCV-21', 'MWH-5', 57, 2.8e-322],
#        ['TMI-43T', 'MWH-4', 65, 3.2e-322],
#        ['TMI-43T', 'MWH-5', 112, 5.53e-322],
#        ['AXCP-78', 'MWH-5', 65, 3.2e-322],
#        ['AXCP-78', 'MWH-5', 70, 3.46e-322],
# ...

# %%
import pandas as pd
import numpy as np

df = pd.DataFrame({
    'A': [1, 2, 3],
    'B': [4, 5, 6]
})

print(df)

# Empty column
empty_arr = np.empty((3,1))

# Stack horizontally
result = np.hstack((df, empty_arr))

print(result)
# Out:
#    A  B
# 0  1  4
# 1  2  5
# 2  3  6
# [[1.e+000 4.e+000 0.e+000]
#  [2.e+000 5.e+000 5.e-324]
#  [3.e+000 6.e+000 0.e+000]]

# %%
df1['Grade'] = np.where((df1['Quantity'] >= 10) & (df1['Quantity'] <= 50), 'A',np.where((df1['Quantity'] > 50) & (df1['Quantity'] <= 100), 'B',np.where(df1['Quantity'] > 100, 'C', 'D')))

df1.head()
# Out:
#   MaterialID Location  Quantity Grade
# 0    AXCP-78    MWH-1        67     B
# 1    AXCP-78    MWH-5        65     B
# 2    TMI-43T    MWH-4        78     B
# 3    TMI-43T    MWH-1       120     C
# 4    SDRT-67    MWH-4        58     B

# %%
df1.head()
# Out:
#   MaterialID Location  Quantity Grade
# 0    AXCP-78    MWH-1        67     B
# 1    AXCP-78    MWH-5        65     B
# 2    TMI-43T    MWH-4        78     B
# 3    TMI-43T    MWH-1       120     C
# 4    SDRT-67    MWH-4        58     B

# %% [markdown]
# for loop is used when we know the number iterations before start the excution of code
# #### while loop runs until condition get True

# %%
grd=[]

for ctr in df.Quantity:
    if ctr<= 50:
        grd.append('A')
    elif ctr <= 100:
        grd.append('B')
    else:
        grd.append('C')

df["Grade"] = grd

df
# Out:
#    MaterialID Location  Quantity Grade
# 0     TMI-43T    MWH-4        34     A
# 1     AXCP-78    MWH-1        67     B
# 2     LXCV-21    MWH-2        27     A
# 3     AXCP-78    MWH-5        65     B
# 4     AXCP-78    MWH-4        36     A
# 5     TMI-43T    MWH-4        78     B
# 6     TMI-43T    MWH-4        31     A
# 7     TMI-43T    MWH-2        29     A
# 8     GCVB-79    MWH-2        10     A
# 9     TMI-43T    MWH-1       120     C
# 10    SDRT-67    MWH-1        34     A
# 11    SDRT-67    MWH-4        58     B
# 12    TMI-43T    MWH-4        76     B
# 13    TMI-43T    MWH-4        32     A
# 14    TMI-43T    MWH-3        65     B
# 15    GCVB-79    MWH-2        87     B
# 16    SDRT-67    MWH-5        12     A
# 17    SDRT-67    MWH-5       102     C
# 18    TMI-43T    MWH-4        34     A
# 19    TMI-43T    MWH-4        52     B
# 20    TMI-43T    MWH-4        39     A
# 21    TMI-43T    MWH-4        75     B
# 22    DDBN-89    MWH-4        48     A
# ...

# %%
df.Grade.value_counts()
# Out:
# Grade
# A    24
# B    20
# C     6
# Name: count, dtype: int64

# %% [markdown]
# ## which ware house have highest quantity also count of ware houses

# %%
## which ware house have highest quantity also count of ware houses

# %%
import seaborn as sns
sns.barplot(df.Quantity)
# Out:
# <Axes: ylabel='Quantity'>

# %%
df = pd.read_excel('/content/drive/MyDrive/CDAC_DataBook.xlsx', sheet_name ='EmpInfo')
df.head()
# Out:
#       Name EmpID    Deptt  Passport
# 0   Sudeep  A342  Quality  DF453278
# 1  Ruchika  C578    Sales  CA567657
# 2      NaN  J436    Admin  DF453278
# 3    Arjun  A342      NaN  RF453432
# 4    Rishi  R475    Prodn  DF453278

# %%
ind = np.where(df.Deptt.isnull())
ind
df1 = df.iloc[ind[0]]
print(df1              ,end='\n\n')

df1= df1.reset_index(drop = True)
df1
# Out:
#      Name EmpID Deptt  Passport
# 3   Arjun  A342   NaN  RF453432
# 5  Chetan   NaN   NaN  ER534867
#      Name EmpID Deptt  Passport
# 0   Arjun  A342   NaN  RF453432
# 1  Chetan   NaN   NaN  ER534867

# %%
ind = np.where((df.Deptt.isnull()) | (df.Name.isnull()) | (df.EmpID.isnull()) | (df.Passport.isnull()) )
print(ind[0])

df.drop(ind[0])
# Out:
# [2 3 5 6]
#       Name EmpID    Deptt  Passport
# 0   Sudeep  A342  Quality  DF453278
# 1  Ruchika  C578    Sales  CA567657
# 4    Rishi  R475    Prodn  DF453278

# %%
ind = np.where((df.Deptt.isnull()) )
ind[0]

df.iloc[ind[0]].reset_index( drop= True)
# Out:
# array([3, 5])

# %% [markdown]
# ⭐===========================================⭐\
# Replace the missing values with other values. \
# if the column is is numerical column we can fill those value s as median. \
# if the column is is string column we can fill those value s as mode \
# ⭐===========================================⭐

# %%
df.loc[ind[0],'Deptt'] = 'Fresher' #This values by Column Name
df
# Out:
#       Name EmpID    Deptt  Passport
# 0   Sudeep  A342  Quality  DF453278
# 1  Ruchika  C578    Sales  CA567657
# 2      NaN  J436    Admin  DF453278
# 3    Arjun  A342  Fresher  RF453432
# 4    Rishi  R475    Prodn  DF453278
# 5   Chetan   NaN  Fresher  ER534867
# 6   Deepak   NaN  Quality  RF453432

# %%
df.iloc[ind[0],2] = 'Fresher' #This values by Column number ** Here we whave to use iloc**
df
# Out:
#       Name EmpID    Deptt  Passport
# 0   Sudeep  A342  Quality  DF453278
# 1  Ruchika  C578    Sales  CA567657
# 2      NaN  J436    Admin  DF453278
# 3    Arjun  A342  Fresher  RF453432
# 4    Rishi  R475    Prodn  DF453278
# 5   Chetan   NaN  Fresher  ER534867
# 6   Deepak   NaN  Quality  RF453432

# %%
df.EmpID.isnull()
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# 5     True
# 6     True
# Name: EmpID, dtype: bool

# %%
#count then null values
ind = np.where(df.EmpID.isnull())
ind
print(len(ind[0]))


#count then null values without len
df.EmpID.isnull().sum()
# Out:
# 2
# np.int64(2)

# %%
## Drop all rows which have one Null value
ind = np.where((df.Deptt.isnull()) | (df.Name.isnull()) | (df.EmpID.isnull()) | (df.Passport.isnull()) )
print(ind[0]                  ,end='\n\n')
print(df.iloc[ind[0]]                   ,end='\n\n')

## Drop all rows which have one Null value
df.dropna()

# this will give number of all missing values and data type
df.info()
# Out:
# [2 5 6]
#
#      Name EmpID    Deptt  Passport
# 2     NaN  J436    Admin  DF453278
# 5  Chetan   NaN  Fresher  ER534867
# 6  Deepak   NaN  Quality  RF453432
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7 entries, 0 to 6
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Name      6 non-null      object
#  1   EmpID     5 non-null      object
#  2   Deptt     7 non-null      object
#  3   Passport  7 non-null      object
# dtypes: object(4)
# memory usage: 356.0+ bytes

# %% [markdown]
# # how to deal with duplicate values

# %%
ind = np.where(df.Passport.duplicated())  # 1st occraunce will not get reported
ind[0]
# Out:
# array([2, 4, 6])

# %%
#ind = np.where(df.Passport.duplicated(keep= 'first')) # 1st occraunce will not get reported

ind = np.where(df.Passport.duplicated(keep= False))  # all occraunce will get reported

#ind = np.where(df.Passport.duplicated(keep= 'last')) # last occraunce will not get reported
ind[0]
print(df.iloc[ind[0]])

print('------------------------------------------------------------------')

df.drop(ind[0])
# Out:
#      Name EmpID    Deptt  Passport
# 0  Sudeep  A342  Quality  DF453278
# 2     NaN  J436    Admin  DF453278
# 3   Arjun  A342  Fresher  RF453432
# 4   Rishi  R475    Prodn  DF453278
# 6  Deepak   NaN  Quality  RF453432
# ------------------------------------------------------------------
#       Name EmpID    Deptt  Passport
# 1  Ruchika  C578    Sales  CA567657
# 5   Chetan   NaN  Fresher  ER534867

# %%
ind = np.where((df.Quantity <100 ) & (df.Quantity >60))

df.iloc[ind[0]].reset_index( drop= True)
# Out:
#    MaterialID Location  Quantity
# 0     AXCP-78    MWH-1        67
# 1     AXCP-78    MWH-5        65
# 2     TMI-43T    MWH-4        78
# 3     TMI-43T    MWH-4        76
# 4     TMI-43T    MWH-3        65
# 5     GCVB-79    MWH-2        87
# 6     TMI-43T    MWH-4        75
# 7     DDBN-89    MWH-5        71
# 8     LXCV-21    MWH-5        83
# 9     TMI-43T    MWH-4        65
# 10    AXCP-78    MWH-5        65
# 11    AXCP-78    MWH-5        70
# 12    DDBN-89    MWH-2        69
# 13    AXCP-78    MWH-2        85
# 14    AXCP-78    MWH-1        75

# %%
df = pd.read_excel('/content/drive/MyDrive/CDAC_DataBook.xlsx' ,sheet_name='ERPData')
df.head(5)
uniq = np.unique(df.Location)
print(uniq)

print()

for i in uniq:
    print(i, max(df.iloc[np.where(df.Location==i)].Quantity))

print()


l={}
for i in uniq:
    l[i]=(sum(df.iloc[np.where(df.Location==i)].Quantity))
print(l)
print(max(l.values()))
# Out:
# ['MWH-1' 'MWH-2' 'MWH-3' 'MWH-4' 'MWH-5']
#
# MWH-1 152
# MWH-2 87
# MWH-3 65
# MWH-4 78
# MWH-5 112
#
# {'MWH-1': 889, 'MWH-2': 397, 'MWH-3': 174, 'MWH-4': 728, 'MWH-5': 697}
# 889

# %%
df = pd.read_excel('/content/drive/MyDrive/pan_card.xlsx')
df.head(5)

ind = np.where(df['PAN Number'].duplicated (keep= False))

df2 = df.drop(ind[0]).reset_index(drop = True)

surname_initial = df2.Name.str.split().str[1].str[0].str.upper()
surname_initial

pan4 = df2['PAN Number'].str[4].str.upper()
pan4

ind = np.where(surname_initial == pan4)

df2.iloc[ind[0]].reset_index(drop = True)
# Out:
#           Name   Father Name                  DOB  PAN Number
# 0   Neha Singh    Anil Singh           21/08/1992  BBBCS5678D
# 1  Priya Gupta  Mahesh Gupta  1995-05-07 00:00:00  DDDPG8765F
# 2   Pooja Nair   Ramesh Nair           25/12/1993  HHHPN8642K
# 3  Divya Joshi  Dinesh Joshi           17/02/1994  JJJDJ4682M
# 4  Arjun Mehta  Rakesh Mehta           19/11/1991  EEEMM2468G
# 5   Sneha Iyer   Ganesh Iyer  1996-03-03 00:00:00  FFFSI1357H
# 6   Rohit Khan    Imran Khan           14/09/1989  GGGPK9753J

# %% [markdown]
# # GroupBy Commands
# category contious descrete \
# quantitive qualitive

# %%
df = pd.read_excel('/content/drive/MyDrive/CDAC_DataBook.xlsx' ,sheet_name='ERPData')
df.head(5)
# Out:
#   MaterialID Location  Quantity
# 0    TMI-43T    MWH-4        34
# 1    AXCP-78    MWH-1        67
# 2    LXCV-21    MWH-2        27
# 3    AXCP-78    MWH-5        65
# 4    AXCP-78    MWH-4        36

# %%
grp1 = df.groupby('Location')
grp1

# %%
grp1.groups
# Out:
# {'MWH-1': [1, 9, 10, 24, 25, 26, 39, 40, 41, 48, 49], 'MWH-2': [2, 7, 8, 15, 35, 36, 42, 45, 46], 'MWH-3': [14, 43, 44, 47], 'MWH-4': [0, 4, 5, 6, 11, 12, 13, 18, 19, 20, 21, 22, 30, 31, 32], 'MWH-5': [3, 16, 17, 23, 27, 28, 29, 33, 34, 37, 38]}

# %%
grp2 = grp1.get_group('MWH-2')
grp3 = grp1.get_group('MWH-3')
grp4 = pd.concat([grp2,grp3])
grp4.reset_index(drop = True)
# Out:
#     index MaterialID Location  Quantity
# 0       1    AXCP-78    MWH-1        67
# 1       9    TMI-43T    MWH-1       120
# 2      10    SDRT-67    MWH-1        34
# 3      24    AXCP-78    MWH-1       152
# 4      25    AXCP-78    MWH-1       109
# 5      26    DDBN-89    MWH-1        57
# 6      39    AXCP-78    MWH-1       145
# 7      40    DDBN-89    MWH-1        34
# 8      41    SDRT-67    MWH-1        57
# 9      48    AXCP-78    MWH-1        75
# 10     49    DDBN-89    MWH-1        39
# 11      2    LXCV-21    MWH-2        27
# 12      7    TMI-43T    MWH-2        29
# 13      8    GCVB-79    MWH-2        10
# 14     15    GCVB-79    MWH-2        87
# 15     35    GCVB-79    MWH-2        31
# 16     36    GCVB-79    MWH-2        28
# 17     42    SDRT-67    MWH-2        31
# 18     45    DDBN-89    MWH-2        69
# 19     46    AXCP-78    MWH-2        85
# 20     14    TMI-43T    MWH-3        65
# 21     43    DDBN-89    MWH-3        38
# ...

# %%
grp4 = pd.concat([ grp1.get_group('MWH-1'), grp1.get_group('MWH-2'),  grp1.get_group('MWH-3') ])
grp4.reset_index()
# Out:
#     index MaterialID Location  Quantity
# 0       1    AXCP-78    MWH-1        67
# 1       9    TMI-43T    MWH-1       120
# 2      10    SDRT-67    MWH-1        34
# 3      24    AXCP-78    MWH-1       152
# 4      25    AXCP-78    MWH-1       109
# 5      26    DDBN-89    MWH-1        57
# 6      39    AXCP-78    MWH-1       145
# 7      40    DDBN-89    MWH-1        34
# 8      41    SDRT-67    MWH-1        57
# 9      48    AXCP-78    MWH-1        75
# 10     49    DDBN-89    MWH-1        39
# 11      2    LXCV-21    MWH-2        27
# 12      7    TMI-43T    MWH-2        29
# 13      8    GCVB-79    MWH-2        10
# 14     15    GCVB-79    MWH-2        87
# 15     35    GCVB-79    MWH-2        31
# 16     36    GCVB-79    MWH-2        28
# 17     42    SDRT-67    MWH-2        31
# 18     45    DDBN-89    MWH-2        69
# 19     46    AXCP-78    MWH-2        85
# 20     14    TMI-43T    MWH-3        65
# 21     43    DDBN-89    MWH-3        38
# ...

# %%
grp1.Quantity.agg('sum')
# Out:
# Location
# MWH-1    889
# MWH-2    397
# MWH-3    174
# MWH-4    728
# MWH-5    697
# Name: Quantity, dtype: int64

# %%
grp1.Quantity.agg(np.size)   # return the count of the occurance
# Out:
# Location
# MWH-1    11
# MWH-2     9
# MWH-3     4
# MWH-4    15
# MWH-5    11
# Name: Quantity, dtype: int64

# %%
grp1.Quantity.agg(np.mean)
# Out:
# /tmp/ipykernel_403/719844975.py:1: FutureWarning: The provided callable <function mean at 0x79703f935940> is currently using SeriesGroupBy.mean. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "mean" instead.
#   grp1.Quantity.agg(np.mean)
# Location
# MWH-1    80.818182
# MWH-2    44.111111
# MWH-3    43.500000
# MWH-4    48.533333
# MWH-5    63.363636
# Name: Quantity, dtype: float64

# %%
grp1.Quantity.agg([ np.sum, np.size , np.mean ])
grp1.Quantity.agg (['sum', 'size' , 'mean'])
# Out:
# /tmp/ipykernel_403/1764219949.py:1: FutureWarning: The provided callable <function sum at 0x79703f934860> is currently using SeriesGroupBy.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "sum" instead.
#   grp1.Quantity.agg([ np.sum, np.size , np.mean ])
# /tmp/ipykernel_403/1764219949.py:1: FutureWarning: The provided callable <function mean at 0x79703f935940> is currently using SeriesGroupBy.mean. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "mean" instead.
#   grp1.Quantity.agg([ np.sum, np.size , np.mean ])
#           sum  size       mean
# Location
# MWH-1     889    11  80.818182
# MWH-2     397     9  44.111111
# MWH-3     174     4  43.500000
# MWH-4     728    15  48.533333
# MWH-5     697    11  63.363636

# %% [markdown]
# labels have
# 1) primary label
# 2) secondary label

# %%
locn1 = ['Mumbai', 'Mumbai', 'Mumbai' ,'Pune' , 'Pune']
course = ['AI' , 'ML' , 'DS' , 'AI' , 'DS']
marks1 = [45 , 65 , 75 , 85 , 60]
marks2 = [40 , 50 , 60 , 70 , 80]

my_df = pd.DataFrame({'Dev': marks1 , 'Arv' : marks2 } , index = [locn1 , course ])
my_df.Arv.mean()
# Out:
# np.float64(60.0)

# %%
my_df.index.names = ['Location' , 'Subject']
my_df
# Out:
#                   Dev  Arv
# Location Subject
# Mumbai   AI        45   40
#          ML        65   50
#          DS        75   60
# Pune     AI        85   70
#          DS        60   80

# %%
my_df.Dev
my_df.loc['Mumbai']
my_df.loc['Mumbai' , 'AI']
# Out:
# Dev    45
# Arv    40
# Name: (Mumbai, AI), dtype: int64

# %%
my_df.xs('ML', level ='Subject')
# Out:
#           Dev  Arv
# Location
# Mumbai     65   50

# %%
my_df.xs('Mumbai' , level = 'Location')
# Out:
#          Dev  Arv
# Subject
# AI        45   40
# ML        65   50
# DS        75   60
