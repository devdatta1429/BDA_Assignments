# %% [markdown]
# <a href="https://colab.research.google.com/github/devdatta1429/BDA_Assignments/blob/main/Python/Day_06_04_Mar.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
class circle:
    def setradius(self):
        self.input= int(input("Enter UR radius"))

    def area(self):
        return self.input*self.input*2*3.14

# %%
c=circle()

# %%
c.setradius()
# Out:
# Enter UR radius12

# %%
c.area()
# Out:
# 904.32

# %%
class calci:
    # def asd(self,name):
    #     name=self.name

    def add(self,n1,n2):
        return n1+n2

    def sub(self,n1,n2):
        return n1-n2

    def mul(self,n1,n2):
        return n1*n2

    def div(self,n1,n2):
        return n1/n2

# %%
c=calci()
c.add(10,20)
# c.sub(10,20)
# c.mul(10,20)
# c.div(10,20)
# Out:
# 30

# %%
class Time:
    def set_time(self,HH,MM,SS):
        self.HH=HH
        self.MM=MM
        self.SS=SS

    def display(self):
        print(self.HH,self.MM,self.SS)

    def in_HH(self):
        self.HH+=1

    def in_MM(self):
        self.MM+=1

    def in_SS(self):
        self.SS+=1

# %%
t = Time()
t.set_time(10, 20, 30)

t.display()

t.in_HH()
t.in_MM()
t.in_SS()

t.display()
# Out:
# 10 20 30
# 11 21 31

# %%
c=Time()
c.set_time(10,12,12)
c.in_HH()
c.display()
# Out:
# 11 12 12

# %%
## Trying by own self
## Trying by own self


class account:
    account_num_gen=202600
    def __init__(self,name,account):
        self.name=name
        self.account=account
        account.account_num_gen+=1

        self.account_num=account.account_num_gen
        print(f"hello {self.name} account is{self.account_num}")

    def check_balance(self):
        print(f"your account number{self.account_num}, your balance is {self.amount}")

# %%
## Menu driven while Ture:
## Menu driven while Ture:

## from IPython.core.compilerop import check_linecache_ipython
bank={}
class Account:
    account_number_generator=202600
    def __init__(self,name,amount):
        self.name=name
        self.amount=amount

        Account.account_number_generator+=1
        self.account_number=Account.account_number_generator
        print(f"Account successfully created. Your account number is {self.account_number}")

    def check_balance(self):
        print(f"your account_number:{self.account_number} has {self.amount}. ")

    def deposite(self,amount):
        if amount>0:
            self.amount+=amount
            self.check_balance()
        else:
            print(f"{amount} not be negative.")
    def withdraw(self,amount):
        if self.amount-amount>3000:
            self.amount-=amount
            self.check_balance()
        else:
            print(f"Low balance, hence transaction cannot be performed")
    def get_account(self):
        return self.account_number


def menu():
    print('''1. Create acc
2. Deposite
3. Withdraw
4. To check balance
5. Transfer
6. To stop''')


while True:
    print("-"*30
          )
    menu()

    comm=int(input(":"))

    if comm==1:
        name=input("Enter your name")
        while True:
            amount=float(input("Enter your balance"))
            if amount >= 3000:
                a=Account(name,amount)
                break
            else:
                print("Amount should be Greater than 3000")
        bank[a.get_account()]=a

    elif comm==2:
        account=int(input("Enter your Account Number:"))
        if account in bank:
            print(f"{account} Found....")
            bank[account].deposite(float(input("Enter Amount:")))
        else:
            print(f"{account} Not Found....")
    elif comm==3:
        account=int(input("Enter Your Account Number:"))
        if account in bank:
            print(f"{account} Found...")
            bank[account].withdraw(float(input("Enter Amount")))
            print()
        else:
            print(f"{account} Not Found...")
    elif comm==4:
        account=int(input("Enyter your account number"))
        if account in bank:
            print(f"{account} Found")
            bank[account].check_balance()
        else:
            print(f"{account} Not Found")

    elif comm==5:
        account1=int(input("Enter sender Account"))
        if account1 in bank:
            print(f"{bank[account1]} Found")

            if bank[account1].amount > 3000:
                print("Ready to transfer")
            else:
                print("Low balance")
        account2=int(input("Enter receiver Account"))
        if account2 in bank:
            print(f"{bank[account2]} also Found..")
        amount=int(input("Enter Your transfer ammount "))
        if (bank[account1].amount-amount)>=3000:
            bank[account1].withdraw(amount)
            bank[account2].deposite(amount)
        else:
            print(f"After the transfer {bank[account1]} ")


    elif comm==6:
        print("Thank you for banking with us.")
        break
    else:
        print("❌❌Wrong Input❌❌")
print(bank.values
 ())

# %%
class voter:
    def __init__(self,name,age):
        self.name=name
        self.age=age

    def __str__(self):
        if self.age>= 18:
            return (f"hello, {self.name}, your age is {self.age}. you can vote")
        else:
            return (f"hello, {self.name}, your age is {self.age}. you can vote")

# %%
v=voter("dev",23)

# %%
class education:
    def __init__(self,education):
        self.education=education
        print(f"{education}")

class salary(education):
    def __init__(self,education,salary):
        self.salary = salary
        super().__init__(education)
        print(f"{salary}")

class human(salary):
    def __init__(self,name,gender,education,salary):
        self.name=name
        self.gender=gender
        super().__init__(education,salary)

    def display(self):
        print(f"{self.name}{self.gender}")
        print(f"{self.education}")
        print(f"{self.salary}")

h=human("dev","male","be",100000)
h.display()
# Out:
# be
# 100000
# devmale
# be
# 100000

# %%
print(v)
# Out:
# hello, dev, your age is 23. you can vote
