# %% [markdown]
# <a href="https://colab.research.google.com/github/devdatta1429/BDA_Assignments/blob/main/Python/Day_08_09_Mar.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <h1>🔰🔴Beautiful Soup🔴🔰

# %%
from bs4 import BeautifulSoup

#Its is used for web Scrapping

# %%
cities='''
<!DOCTYPE html>
<html lang="en">
<head>
    <meta charset="UTF-8">
    <meta name="viewport" content="width=device-width, initial-scale=1.0">
    <title>Indian States and Cities</title>
    <style>
        body {
            font-family: Arial, sans-serif;
            margin: 20px;
            padding: 20px;
        }
        h2 {
            color: #007bff;
        }
    </style>
</head>
<body>
    <h1>List of Cities in Each State of India</h1>
    <ol>
        <li>
            <h2>Maharashtra</h2>
            <ol>
                <li>Mumbai</li>
                <li>Pune</li>
                <li>Nagpur</li>
                <li>Nashik</li>
                <li>Aurangabad</li>
            </ol>
        </li>
        <li>
            <h2>Karnataka</h2>
            <ol>
                <li>Bengaluru</li>
                <li>Mysuru</li>
                <li>Hubballi</li>
                <li>Mangaluru</li>
                <li>Belagavi</li>
            </ol>
        </li>
        <li>
            <h2>Tamil Nadu</h2>
            <ol>
                <li>Chennai</li>
                <li>Coimbatore</li>
                <li>Madurai</li>
                <li>Tiruchirappalli</li>
                <li>Salem</li>
            </ol>
        </li>
        <li>
            <h2>Uttar Pradesh</h2>
            <ol>
                <li>Lucknow</li>
                <li>Kanpur</li>
                <li>Varanasi</li>
                <li>Agra</li>
                <li>Meerut</li>
            </ol>
        </li>
        <li>
            <h2>West Bengal</h2>
            <ol>
                <li>Kolkata</li>
                <li>Howrah</li>
                <li>Darjeeling</li>
                <li>Asansol</li>
                <li>Siliguri</li>
            </ol>
        </li>
    </ol>
</body>
</html>
'''

# %%
html_doc = """
<html>
<head>
<title>My Website</title>
</head>
<body>
<div id="content">
<h1>Welcome to my website!</h1>
<p>This is a paragraph of text.</p>
<a href="http://www.google.com">Google</a>
</div>
<div id="content2">
<h1>zingalala</h1>
</div>
</body>
</html>
"""

# %%
from bs4 import BeautifulSoup
soup=BeautifulSoup(cities,'html.parser')
li_tags=soup.find_all('li')#list

list_text=[]

for li_tag in li_tags:#taken one item at a time
    for item in li_tag.find_all("h2"):
        list_text.append(item.text)
        inneritem=[]
        for item1 in li_tag.find_all("li"):
            inneritem.append(item1.text)
        list_text.append(inneritem)
        # inneritem.clear()
        #item has.text
print( list_text)
print()
for i in range(0,len(list_text)):
    if i%2==0:
        print(list_text[i])
    else:
        print(list_text[i])
# Out:
# ['Maharashtra', ['Mumbai', 'Pune', 'Nagpur', 'Nashik', 'Aurangabad'], 'Karnataka', ['Bengaluru', 'Mysuru', 'Hubballi', 'Mangaluru', 'Belagavi'], 'Tamil Nadu', ['Chennai', 'Coimbatore', 'Madurai', 'Tiruchirappalli', 'Salem'], 'Uttar Pradesh', ['Lucknow', 'Kanpur', 'Varanasi', 'Agra', 'Meerut'], 'West Bengal', ['Kolkata', 'Howrah', 'Darjeeling', 'Asansol', 'Siliguri']]
#
# Maharashtra
# ['Mumbai', 'Pune', 'Nagpur', 'Nashik', 'Aurangabad']
# Karnataka
# ['Bengaluru', 'Mysuru', 'Hubballi', 'Mangaluru', 'Belagavi']
# Tamil Nadu
# ['Chennai', 'Coimbatore', 'Madurai', 'Tiruchirappalli', 'Salem']
# Uttar Pradesh
# ['Lucknow', 'Kanpur', 'Varanasi', 'Agra', 'Meerut']
# West Bengal
# ['Kolkata', 'Howrah', 'Darjeeling', 'Asansol', 'Siliguri']
