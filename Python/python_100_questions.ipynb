# %% [markdown]
# <a href="https://colab.research.google.com/github/devdatta1429/BDA_Assignments/blob/main/Python/python_100_questions.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 🐍 100 Python Coding Questions for Freshers
# Each question is in its own cell. Write your solution below each question comment and run the cell to test it.

# %%
# Q1. Write a Python program to print "Hello, World!".

# %%
# Q2. Write a program to check if a number is even or odd.

# %%
# Q3. Write a program to find the factorial of a number.

# %%
# Q4. Write a program to check if a string is a palindrome.

# %%
# Q5. Write a program to find the largest element in an array.

# %%
# Q6. Write a program to reverse a string.

# %%
# Q7. Write a program to check if a number is prime.

# %%
# Q8. Write a program to find the sum of all elements in an array.

# %%
# Q9. Write a program to check if a string is an anagram.

# %%
# Q10. Write a program to calculate the square root of a number.

# %%
# Q11. Write a program to count the number of vowels in a string.

# %%
# Q12. Write a program to find the second largest element in an array.

# %%
# Q13. Write a program to find the sum of all even numbers in an array.

# %%
# Q14. Write a program to check if a year is a leap year.

# %%
# Q15. Write a program to calculate the factorial of a number using recursion.

# %%
# Q16. Write a program to find the length of a string.

# %%
# Q17. Write a program to find the GCD (Greatest Common Divisor) of two numbers.

# %%
# Q18. Write a program to remove duplicate elements from an array.

# %%
# Q19. Write a program to check if a string is a palindrome without using any built-in functions.

# %%
# Q20. Write a program to find the sum of the digits of a number.

# %%
# Q21. Write a program to find the average of elements in an array.

# %%
# Q22. Write a program to check if a number is a perfect number.

# %%
# Q23. Write a program to sort elements in an array in ascending order.

# %%
# Q24. Write a program to check if a string is a valid email address.

# %%
# Q25. Write a program to find the maximum of three numbers.

# %%
# Q26. Write a program to check if a number is an Armstrong number.

# %%
# Q27. Write a program to find the Fibonacci series up to a given number.

# %%
# Q28. Write a program to reverse a number.

# %%
# Q29. Write a program to find the number of words in a string.

# %%
# Q30. Write a program to check if a string contains only digits.

# %%
# Q31. Write a program to find the sum of all prime numbers up to a given number.

# %%
# Q32. Write a program to check if a number is a perfect square.

# %%
# Q33. Write a program to convert a string to uppercase.

# %%
# Q34. Write a program to find the intersection of two arrays.

# %%
# Q35. Write a program to check if a number is a strong number.
# (Strong number: sum of factorial of digits equals the number itself, e.g. 145 = 1! + 4! + 5!)

# %%
# Q36. Write a program to count the number of occurrences of a character in a string.

# %%
# Q37. Write a program to find the reverse of an array.

# %%
# Q38. Write a program to check if a string is a valid palindrome.

# %%
# Q39. Write a program to check if a number is a happy number.
# (Happy number: repeatedly sum squares of digits until result is 1 or loops endlessly)

# %%
# Q40. Write a program to find the LCM (Least Common Multiple) of two numbers.

# %%
# Q41. Write a program to find the square of a number without using the multiplication operator.

# %%
# Q42. Write a program to check if a string is a valid URL.

# %%
# Q43. Write a program to find the number of uppercase and lowercase letters in a string.

# %%
# Q44. Write a program to check if a number is a perfect cube.

# %%
# Q45. Write a program to find the sum of natural numbers up to a given number.

# %%
# Q46. Write a program to check if a string is a valid palindrome ignoring spaces and punctuation.

# %%
# Q47. Write a program to check if a number is a happy prime.
# (Happy prime: a number that is both happy and prime)

# %%
# Q48. Write a program to find the sum of digits in a string.

# %%
# Q49. Write a program to check if a number is a strong prime.
# (Strong prime: a prime that is greater than the average of the nearest primes on either side)

# %%
# Q50. Write a program to generate a Fibonacci series up to a given number.

# %%
# Q51. Write a program to find the product of two numbers without using the multiplication operator.

# %%
# Q52. Write a program to check if a string is a valid IP address.

# %%
# Q53. Write a program to find the ASCII value of a character.

# %%
# Q54. Write a program to count the number of occurrences of each element in an array.

# %%
# Q55. Write a program to check if a number is a palindrome.

# %%
# Q56. Write a program to find the power of a number using recursion.

# %%
# Q57. Write a program to convert a decimal number to binary.

# %%
# Q58. Write a program to check if a string is a valid palindrome using recursion.

# %%
# Q59. Write a program to find the sum of all natural numbers between two given numbers.

# %%
# Q60. Write a program to find the largest prime factor of a number.

# %%
# Q61. Write a program to check if a string is a valid password.
# Criteria: minimum 8 chars, has uppercase, lowercase, digit, and special character.

# %%
# Q62. Write a program to find the number of trailing zeros in the factorial of a number.

# %%
# Q63. Write a program to find the sum of all digits in a number until it becomes a single-digit number.

# %%
# Q64. Write a program to check if a number is a perfect number using recursion.

# %%
# Q65. Write a program to find the binary representation of a decimal number using recursion.

# %%
# Q66. Write a program to find the number of words in a sentence.

# %%
# Q67. Write a program to find the sum of the series: 1 + 1/2 + 1/3 + ... + 1/n.

# %%
# Q68. Write a program to find the number of digits in a given number.

# %%
# Q69. Write a program to find the frequency of a given element in an array.

# %%
# Q70. Write a program to check if a string is an isogram (no repeating characters).

# %%
# Q71. Write a program to find the median of an array.

# %%
# Q72. Write a program to check if a number is a palindrome in binary representation.

# %%
# Q73. Write a program to find the number of times a substring appears in a given string.

# %%
# Q74. Write a program to find the sum of the series: 1 - 1/2 + 1/3 - ... + (-1)^n/n.

# %%
# Q75. Write a program to find the common elements between two arrays.

# %%
# Q76. Write a program to convert a binary number to decimal.

# %%
# Q77. Write a program to check if a string is a valid credit card number.
# (Use Luhn Algorithm)

# %%
# Q78. Write a program to find the ASCII value of all characters in a string.

# %%
# Q79. Write a program to find the roots of a quadratic equation.
# ax^2 + bx + c = 0

# %%
# Q80. Write a program to find the sum of all prime numbers between two given numbers.

# %%
# Q81. Write a program to find the sum of the series: 1^1 + 2^2 + 3^3 + ... + n^n.

# %%
# Q82. Write a program to check if a string is a valid palindrome using stack data structure.

# %%
# Q83. Write a program to find the number of occurrences of a substring in a given string.

# %%
# Q84. Write a program to check if a number is a Smith number.
# (Smith number: composite number where sum of digits equals sum of digits of its prime factors)

# %%
# Q85. Write a program to find the length of the last word in a string.

# %%
# Q86. Write a program to check if a number is a palindrome in both decimal and binary representation.

# %%
# Q87. Write a program to find the number of prime numbers up to a given limit.

# %%
# Q88. Write a program to find the sum of all elements in a matrix.

# %%
# Q89. Write a program to check if a string is a valid IPv4 address.

# %%
# Q90. Write a program to find the difference between the sum of squares and the square of the sum of n natural numbers.

# %%
# Q91. Write a program to find the sum of the series: 1/1! + 1/2! + 1/3! + ... + 1/n!.

# %%
# Q92. Write a program to check if a number is a narcissistic number.
# (Narcissistic number: sum of its own digits each raised to the power of the number of digits equals the number)

# %%
# Q93. Write a program to find the maximum difference between any two elements in an array.

# %%
# Q94. Write a program to check if a string is a pangram (contains all the letters of the alphabet).

# %%
# Q95. Write a program to find the number of trailing zeros in the factorial of a number using recursion.

# %%
# Q96. Write a program to check if a number is a palindrome in hexadecimal representation.

# %%
# Q97. Write a program to find the sum of the digits of a number until it becomes a single-digit number using recursion.

# %%
# Q98. Write a program to find the number of occurrences of each character in a string.

# %%
# Q99. Write a program to find the product of two matrices.

# %%
# Q100. Write a program to check if a number is a Harshad number.
# (Harshad number: divisible by the sum of its digits. E.g., 18 is Harshad because 1+8=9 and 18/9=2)
